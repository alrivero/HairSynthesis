# %%
import os
import math
import json
import numpy as np
import imageio.v2 as imageio
import matplotlib.pyplot as plt

# %%
ROOT_DIR = "/gpfs/projects/CascanteBonillaGroup/thinguyen/datasets/FFHQ256"
image_name = "00588.png"

input_img = imageio.imread(os.path.join(ROOT_DIR, 'processed', 'hairstep', 'resized_img', image_name))
hairmask = imageio.imread(os.path.join(ROOT_DIR, 'processed', 'hairstep', 'seg', image_name))
hairmask = (hairmask / 255)>0.5

# %%
plt.imshow(hairmask, cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
img_hair = input_img * (1-hairmask[...,None])
plt.imshow(img_hair)
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)
